# %% [markdown]
# # Tokenization

# %% [markdown]
# ## With NLTK

# %%
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
import nltk
from nltk.tokenize import word_tokenize, sent_tokenize

# %%
para = "Lorem Ipsum is simply dummy text of the printing and typesetting industry. Lorem Ipsum has been the industry's standard dummy text ever since the 1500s, when an unknown printer took a galley of type and scrambled it to make a type specimen book. It has survived not only five centuries, but also the leap into electronic typesetting, remaining essentially unchanged. It was popularised in the 1960s with the release of Letraset sheets containing Lorem Ipsum passages, and more recently with desktop publishing software like Aldus PageMaker including versions of Lorem Ipsum."
sents = sent_tokenize(para)
print(sents)
# Out:
# ['Lorem Ipsum is simply dummy text of the printing and typesetting industry.', "Lorem Ipsum has been the industry's standard dummy text ever since the 1500s, when an unknown printer took a galley of type and scrambled it to make a type specimen book.", 'It has survived not only five centuries, but also the leap into electronic typesetting, remaining essentially unchanged.', 'It was popularised in the 1960s with the release of Letraset sheets containing Lorem Ipsum passages, and more recently with desktop publishing software like Aldus PageMaker including versions of Lorem Ipsum.']

# %%
for sent in sents:
  print(word_tokenize(sent))
# Out:
# ['Lorem', 'Ipsum', 'is', 'simply', 'dummy', 'text', 'of', 'the', 'printing', 'and', 'typesetting', 'industry', '.']
# ['Lorem', 'Ipsum', 'has', 'been', 'the', 'industry', "'s", 'standard', 'dummy', 'text', 'ever', 'since', 'the', '1500s', ',', 'when', 'an', 'unknown', 'printer', 'took', 'a', 'galley', 'of', 'type', 'and', 'scrambled', 'it', 'to', 'make', 'a', 'type', 'specimen', 'book', '.']
# ['It', 'has', 'survived', 'not', 'only', 'five', 'centuries', ',', 'but', 'also', 'the', 'leap', 'into', 'electronic', 'typesetting', ',', 'remaining', 'essentially', 'unchanged', '.']
# ['It', 'was', 'popularised', 'in', 'the', '1960s', 'with', 'the', 'release', 'of', 'Letraset', 'sheets', 'containing', 'Lorem', 'Ipsum', 'passages', ',', 'and', 'more', 'recently', 'with', 'desktop', 'publishing', 'software', 'like', 'Aldus', 'PageMaker', 'including', 'versions', 'of', 'Lorem', 'Ipsum', '.']

# %% [markdown]
# ## With Spacy

# %%
import spacy
nlp = spacy.load('en_core_web_sm')
text = 'I was doing M.phil in London with paying $500.90'
text2 = 'Hey! How are you? i am fine!! what about you?'

# %%
doc = nlp(text)
doc2 = nlp(text2)
for txt in doc2:
  print(txt)
# Out:
# Hey
# !
# How
# are
# you
# ?
# i
# am
# fine
# !
# !
# what
# about
# you
# ?

# %% [markdown]
# # Lowercasing

# %%
import pandas as pd

data = {
    "Review": [
        "The movie was absolutely amazing, the storyline kept me hooked.",
        "I really loved the acting, especially the main character.",
        "The visuals were stunning but the story was quite weak.",
        "It was a complete waste of time, very boring plot.",
        "It was a complete waste of time, very boring plot.",
        "The ending was unexpected and brilliant.",
        "Too long and slow, I almost fell asleep.",
        "The music was good but everything else felt average.",
        "I hated the movie, nothing made sense.",
        "One of the best movies I have seen this year."
    ],
    "Sentiment": [
        "Positive","Positive","Neutral","Negative","Positive",
        "Positive","Negative","Neutral","Negative","Positive"
    ]
}

df = pd.DataFrame(data)

print(df.head())
# Out:
#                                               Review Sentiment
# 0  The movie was absolutely amazing, the storylin...  Positive
# 1  I really loved the acting, especially the main...  Positive
# 2  The visuals were stunning but the story was qu...   Neutral
# 3  It was a complete waste of time, very boring p...  Negative
# 4  It was a complete waste of time, very boring p...  Positive

# %%
df = df['Review'].str.lower()

# %%
df.head(5)
# Out:
# 0    the movie was absolutely amazing, the storylin...
# 1    i really loved the acting, especially the main...
# 2    the visuals were stunning but the story was qu...
# 3    it was a complete waste of time, very boring p...
# 4    it was a complete waste of time, very boring p...
# Name: Review, dtype: object

# %% [markdown]
# # Spell Correction

# %%
from textblob import TextBlob
text = 'Last niggt we met but niw where arw yoo?'
textblob = TextBlob(text)
textblob.correct().string
# Out:
# 'Last night we met but now where are you?'

# %% [markdown]
# # Removing Stopwards

# %%
from nltk.corpus import stopwords
nltk.download('stopwords')
stopword = stopwords.words('english')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
def remove_stopword(text):
    new_text = []

    for word in text.split():
        if word not in stopword:
            new_text.append(word)

    return " ".join(new_text)
remove_stopword("Lorem Ipsum is simply dummy text of the printing and typesetting industry. Lorem Ipsum has been the industry")
# Out:
# 'Lorem Ipsum simply dummy text printing typesetting industry. Lorem Ipsum industry'

# %% [markdown]
# # Stemming

# %%
def stem_word(text10):
  return ' '.join([ps.stem(word) for word in text10.split()])

# %%
from nltk.stem import PorterStemmer
ps = PorterStemmer()

# %%
sample = 'talk talking talked talks'
stem_word(sample)
# Out:
# 'talk talk talk talk'

# %% [markdown]
# # Lemmatization

# %%
import nltk
from nltk.stem import WordNetLemmatizer
from nltk.corpus import wordnet
nltk.download('averaged_perceptron_tagger_eng')

wnl = WordNetLemmatizer()

# POS mapping function
def get_wordnet_pos(tag):
    if tag.startswith('J'):
        return wordnet.ADJ
    elif tag.startswith('V'):
        return wordnet.VERB
    elif tag.startswith('N'):
        return wordnet.NOUN
    elif tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN  # default

text = "Yesterday, i went to walk and there i saw a bird who was chirping. I felt so glad to see it."

# Tokenize
words = nltk.word_tokenize(text)

# Remove punctuation
words = [word for word in words if word.isalnum()]

# POS tagging
pos_tags = nltk.pos_tag(words)

# Lemmatization with correct POS
for word, tag in pos_tags:
    print(f"{word} : {wnl.lemmatize(word, get_wordnet_pos(tag))}")
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger_eng.zip.
# Yesterday : Yesterday
# i : i
# went : go
# to : to
# walk : walk
# and : and
# there : there
# i : i
# saw : saw
# a : a
# bird : bird
# who : who
# was : be
# chirping : chirp
# I : I
# felt : felt
# so : so
# glad : glad
# to : to
# see : see
# it : it
